# %%
import os
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
os.chdir(r"C:\Users\skmoon\Desktop\Virtual\meta")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

print(all_filenames)
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])

#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
combined_csv.head()

# %%
combined_csv.isnull().sum()
# Out:
# 시간                 0
# 내부온도관측치            6
# 외부온도관측치            4
# 내부습도관측치            4
# 외부습도관측치         5200
# CO2관측치             4
# EC관측치              4
# 최근분무량              0
# 화이트 LED동작강도      894
# 레드 LED동작강도       916
# 블루 LED동작강도     10438
# 냉방온도             430
# 냉방부하             430
# 난방온도             430
# 난방부하             432
# 총추정광량            430
# 백색광추정광량          430
# 적색광추정광량          430
# 청색광추정광량        25920
# dtype: int64

# %%
combined_csv.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\skmoon\Desktop\Virtual\plant.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/skmoon/Desktop/Virtual/plant.ipynb#ch0000002?line=0'>1</a> combined_csv.info()
#
# NameError: name 'combined_csv' is not defined

# %%
sns.heatmap(combined_csv.isnull(), cbar = False, cmap="YlGnBu")

# %%
submission = pd.read_excel('./sampledata.xlsx')
plt.rc("font", family = "Malgun Gothic")
sns.heatmap(submission.isnull(), cbar = False, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
plt.rc("font", family = "Malgun Gothic")
plt.figure(figsize=(10,10))
sns.heatmap(combined_csv.corr(), cbar = True, cmap = 'Blues', annot = True)
# Out:
# c:\Users\skmoon\Desktop\Virtual\.venv\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# c:\Users\skmoon\Desktop\Virtual\.venv\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.hist(figsize=(20,20), xrot=45)
plt.show()

# %%
df2 = combined_csv.drop(['시간', '외부습도관측치'], 1)
df2.plot(figsize=(20,20))
# Out:
# C:\Users\skmoon\AppData\Local\Temp\ipykernel_12024\3221220905.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2 = combined_csv.drop(['시간', '외부습도관측치'], 1)
# <AxesSubplot:>
